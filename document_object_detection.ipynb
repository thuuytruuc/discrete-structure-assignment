# %% [markdown]
# <a href="https://colab.research.google.com/github/thuuytruuc/discrete-structure-assignment/blob/main/document_object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **initial setup**

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.0 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.cuda.is_available(), torch.cuda.get_device_name(0))
# Out:
# True Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**subset1-train2**:
# small-object focused with mild augmentation
# - imgsz: 960
# - optimizer: AdamW, lr0=0.0005, weight_decay=0.0005
# - cos_lr: True, rf=0.01
# - mosaic=0.3
# - hsv_h=0.0, hsv_s=0.1, hsv_v=0.1
# - scale=0.2, translate=0.05, fliplr=0.1

# %%
# !yolo detect train \
  cfg = "/content/drive/MyDrive/Colab Notebooks/config.yaml" \
  pretrained = "/content/drive/MyDrive/Colab Notebooks/subset1-train2/weights/best.pt"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Overriding /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/default.yaml with /content/drive/MyDrive/Colab Notebooks/config.yaml
# Transferred 389/437 items from pretrained weights
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# #**subset1-train3**
# - imgsz=640
# - optimizer=SGD, lr0=0.01, weight_decay=0.0005, momentum=0.937
# - cos_lr=False
# - mosaic=1.0, hsv_s=0.5, hsv_v=0.3
# - model=yolov8n.pt

# %%
# !yolo detect train \
  cfg="/content/drive/MyDrive/Colab Notebooks/config.yaml" \
  imgsz=640 \
  optimizer=SGD \
  lr0=0.01 \
  weight_decay=0.0005 \
  momentum=0.937 \
  cos_lr=False \
  mosaic=1.0 \
  hsv_s=0.5 \
  hsv_v=0.3 \
  model=yolov8n.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Overriding /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/default.yaml with /content/drive/MyDrive/Colab Notebooks/config.yaml
# ...
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# #**subset1-train3-resume**

# %%
# !yolo detect train \
  model = "/content/drive/MyDrive/Colab Notebooks/subset1-train3/weights/last.pt" \
  resume = True
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# #**SUBSET2**

# %% [markdown]
# #**subset2-train**
# - imgsz: 960
# - lr0: 0.0007, weight_decay: 0.005, cos_lr: True, lrf: 0.01
# - mosaic: 1.0, hsv_h: 0.015, hsv_s: 0.7, hsv_v: 0.5
# - scale: 0.5, translate: 0.1, fliplr: 0.5

# %%
# !yolo detect train \
  cfg = "/content/drive/MyDrive/Colab Notebooks/config.yaml" \
  pretrained = True \
  lr0: 0.0007 \
  cos_lr: True \
  mosaic: 1.0 \
  hsv_s: 0.7 \
  hsv_v: 0.5 \
  scale: 0.5 \
  translate: 0.1 \
  fliplr: 0.5 \
  weight_decay: 0.005
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Overriding /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/default.yaml with /content/drive/MyDrive/Colab Notebooks/subset2-train.yaml
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train \
  cfg ="/content/drive/MyDrive/Colab Notebooks/subset2-train.yaml" \
  pretrained = "/content/drive/MyDrive/Colab Notebooks/subset2-train/weights/best" \
  epochs = 89 \
  name = subset2-train-continue
# Out:
# Overriding /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/default.yaml with /content/drive/MyDrive/Colab Notebooks/subset2-train.yaml
# Transferred 389/437 items from pretrained weights
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # **full-dataset-train**
# - imgsz: 960
# - optimizer: AdamW, lr0=0.0005, weight_decay=0.0005
# - cos_lr: True, rf=0.01
# - mosaic=0.3
# - hsv_h=0.0, hsv_s=0.1, hsv_v=0.1
# - scale=0.2, translate=0.05, fliplr=0.1

# %%
# !yolo detect train \
  cfg = "/content/drive/MyDrive/Colab Notebooks/config.yaml"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Overriding /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/default.yaml with /content/drive/MyDrive/Colab Notebooks/config.yaml
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train \
  cfg="/content/drive/MyDrive/Colab Notebooks/config.yaml" \
  model="/content/drive/MyDrive/Colab Notebooks/final-train5/weights/last.pt" \
  resume=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Overriding /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/default.yaml with /content/drive/MyDrive/Colab Notebooks/config.yaml
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
